# %%
parse through course descriptions
for each match, add a count then normalize at end?

# %%
import numpy as np
import pandas as pd

# %%
riasec_words = pd.read_excel('RIASEC_words.xlsx', index_col=0)

# %%
riasec_dict = {}
for let in set(riasec_words.index):
    riasec_dict[let] = riasec_words.loc[let]['Word'].tolist()

# %%
courses = {}
course id: riasec{}

# %%
program = {}
program id: riasec{}
