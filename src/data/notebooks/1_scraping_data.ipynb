# %% [markdown]
# # Scraping of Programmes and Courses Data
#
# Notebook pipeline that
#
# 1) Loads both pages in studiegids and collects all programme URLs
# 2) Clicks through every programme, then every track, then every year, and reads the visible tables
# 3) Enriches each programme with text from vu.nl base, curriculum, future, and admissions
# 4) Saves tidy CSV and JSON for programmes and subjects

# %% [markdown]
# ## 1) Import modules

# %%
import pandas as pd
from pathlib import Path
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

from scraper_modules.studiegids import StudiegidsScraper
from scraper_modules.vu_pages import VuPages

# %% [markdown]
# ## 2) Setup directories, Selenium, Faculties

# %%
DATA_DIR = Path("data")
CACHE_DIR = DATA_DIR / "vu_cache"
DATA_DIR.mkdir(exist_ok=True, parents=True)

chrome_options = Options()
# chrome_options.add_argument("--headless=new")  # turn on in CI runs
chrome_options.add_argument("--start-maximized")
driver = webdriver.Chrome(options=chrome_options)

sg = StudiegidsScraper(driver, debug=False)
vu = VuPages(CACHE_DIR)

LISTING_URL = "https://studiegids.vu.nl/en/bachelor/2025-2026#/"
FACULTIES = ["School of Business and Economics", "Faculty of Science", "Faculty of Humanities"]

# %% [markdown]
# ## 3) Programmes list

# %%
programmes = sg.list_programmes(LISTING_URL, FACULTIES)
len(programmes), programmes[:3]
# Out:
# (17,
#  [{'title': 'Ancient Studies',
#    'url': 'https://studiegids.vu.nl/en/Bachelor/2025-2026/ancient-studies'},
#   {'title': 'Archaeology',
#    'url': 'https://studiegids.vu.nl/en/Bachelor/2025-2026/archaeology'},
#   {'title': 'Artificial Intelligence',
#    'url': 'https://studiegids.vu.nl/en/Bachelor/2025-2026/artificial-intelligence'}])

# %% [markdown]
# ## 4) Test only the three titles you mentioned

# %%
TEST_TITLES = {
    "Biomedical Sciences",
    "Philosophy, Politics and Economics",
    "Computer Science",
}
test_programmes = [p for p in programmes if p["title"] in TEST_TITLES]
test_programmes
# Out:
# [{'title': 'Biomedical Sciences',
#   'url': 'https://studiegids.vu.nl/en/Bachelor/2025-2026/biomedical-sciences'},
#  {'title': 'Computer Science',
#   'url': 'https://studiegids.vu.nl/en/Bachelor/2025-2026/computer-science'},
#  {'title': 'Philosophy, Politics and Economics',
#   'url': 'https://studiegids.vu.nl/en/Bachelor/2025-2026/philosophy-politics-and-economics'}]

# %%
rows_subj = []
rows_prog = []

for item in test_programmes:
    title, url = item["title"], item["url"]
    rows = sg.parse_programme_studiegids(url, skip_honors=False, include_minors=True)
    print(f"{title} rows captured:", len(rows))
    for r in rows:
        r["programme_title"] = title
        r["programme_url"] = url
        rows_subj.append(r)
    # add what you were already collecting from tab two and vu pages if needed

df_subj = pd.DataFrame(rows_subj)
df_subj.head(10)
# Out:
# Biomedical Sciences rows captured: 240
# Computer Science rows captured: 145
# Philosophy, Politics and Economics rows captured: 37
#                              course_name  period  ects          code track  \
# 0                Biochemistry - Research     5.0     6       AB_1164
# 1        Biomedical Sciences and Society     5.0     6       AB_1315
# 2  Science Communication for Researchers     5.0     6     AB_470185
# 3                  English Language Test     1.0     0        VU_ELT
# 4                               Genetics     1.0     6       AB_1135
# 5    Introduction to Biomedical Sciences     1.0     6       AB_1136
# 6                             Lab safety     1.0     0  AB_LABSAFETY
# 7                           Biochemistry     2.0     6       AB_1137
# 8               Cell Biology - Histology     2.0     6       AB_1138
# 9        Research in Biomedical Sciences     3.0     6       AB_1142
#
#                                       year_label      programme_title  \
# 0  Biomedical Sciences year 1 constrained choice  Biomedical Sciences
# 1  Biomedical Sciences year 1 constrained choice  Biomedical Sciences
# 2  Biomedical Sciences year 1 constrained choice  Biomedical Sciences
# 3  Biomedical Sciences year 1 compulsory courses  Biomedical Sciences
# 4  Biomedical Sciences year 1 compulsory courses  Biomedical Sciences
# 5  Biomedical Sciences year 1 compulsory courses  Biomedical Sciences
# 6  Biomedical Sciences year 1 compulsory courses  Biomedical Sciences
# 7  Biomedical Sciences year 1 compulsory courses  Biomedical Sciences
# 8  Biomedical Sciences year 1 compulsory courses  Biomedical Sciences
# 9  Biomedical Sciences year 1 compulsory courses  Biomedical Sciences
#
#                                        programme_url
# 0  https://studiegids.vu.nl/en/Bachelor/2025-2026...
# 1  https://studiegids.vu.nl/en/Bachelor/2025-2026...
# 2  https://studiegids.vu.nl/en/Bachelor/2025-2026...
# 3  https://studiegids.vu.nl/en/Bachelor/2025-2026...
# 4  https://studiegids.vu.nl/en/Bachelor/2025-2026...
# 5  https://studiegids.vu.nl/en/Bachelor/2025-2026...
# 6  https://studiegids.vu.nl/en/Bachelor/2025-2026...
# 7  https://studiegids.vu.nl/en/Bachelor/2025-2026...
# 8  https://studiegids.vu.nl/en/Bachelor/2025-2026...
# 9  https://studiegids.vu.nl/en/Bachelor/2025-2026...

# %%
rows_subj = []
for item in programmes:
    title, url = item["title"], item["url"]
    rows = sg.parse_programme_studiegids(url, skip_honors=False)
    for r in rows:
        r["programme_title"] = title
        r["programme_url"] = url
        rows_subj.append(r)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 for item in programmes:
#       3     title, url = item["title"], item["url"]
# ----> 4     rows = sg.parse_programme_studiegids(url, skip_honors=False)
#       5     for r in rows:
#       6         r["programme_title"] = title
#
# File c:\Users\lmo820\OneDrive - Vrije Universiteit Amsterdam\Desktop\vita-vu.github.io\src\data\notebooks\scraper_modules\studiegids.py:557, in StudiegidsScraper.parse_programme_studiegids(self, url, skip_honors, include_minors)
#     555     top_css = f"{ROOT} .accordion > div:nth-child({idx})"
#     556     # do not pre filter minors here, the user asked to include all sections
# --> 557     walk(top_css, [], 0)
#     559 return out
#     562 return out
#
# File c:\Users\lmo820\OneDrive - Vrije Universiteit Amsterdam\Desktop\vita-vu.github.io\src\data\notebooks\scraper_modules\studiegids.py:545, in StudiegidsScraper.parse_programme_studiegids.<locals>.walk(container_css, stack, depth)
#     543 # recurse into children if any
#     544 for child_css in child_selectors(container_css):
# --> 545     walk(child_css, stack + [title], depth + 1)
#
# File c:\Users\lmo820\OneDrive - Vrije Universiteit Amsterdam\Desktop\vita-vu.github.io\src\data\notebooks\scraper_modules\studiegids.py:545, in StudiegidsScraper.parse_programme_studiegids.<locals>.walk(container_css, stack, depth)
#     543 # recurse into children if any
#     544 for child_css in child_selectors(container_css):
# --> 545     walk(child_css, stack + [title], depth + 1)
#
# File c:\Users\lmo820\OneDrive - Vrije Universiteit Amsterdam\Desktop\vita-vu.github.io\src\data\notebooks\scraper_modules\studiegids.py:541, in StudiegidsScraper.parse_programme_studiegids.<locals>.walk(container_css, stack, depth)
#     538     return
#     540 click_header(container_css)
# --> 541 scrape_now(stack + [title])
#     543 # recurse into children if any
#     544 for child_css in child_selectors(container_css):
#
# File c:\Users\lmo820\OneDrive - Vrije Universiteit Amsterdam\Desktop\vita-vu.github.io\src\data\notebooks\scraper_modules\studiegids.py:456, in StudiegidsScraper.parse_programme_studiegids.<locals>.scrape_now(stack)
#     454 if len(tds) > 3:
#     455     try:
# --> 456         code = tds[3].find_element(By.CSS_SELECTOR, "a").text.strip()
#     457     except Exception:
#     458         code = tds[3].text.strip()
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webelement.py:601, in WebElement.find_element(self, by, value)
#     575 """Find an element given a By strategy and locator.
#     576
#     577 Parameters:
#    (...)    598     The first matching `WebElement` found on the page.
#     599 """
#     600 by, value = self._parent.locator_converter.convert(by, value)
# --> 601 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webelement.py:572, in WebElement._execute(self, command, params)
#     570     params = {}
#     571 params["id"] = self._id
# --> 572 return self._parent.execute(command, params)
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.execute(self, driver_command, params)
#     452     elif "sessionId" not in params:
#     453         params["sessionId"] = self.session_id
# --> 455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
#     458     self.error_handler.check_response(response)
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:407, in RemoteConnection.execute(self, command, params)
#     405 trimmed = self._trim_large_entries(params)
#     406 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 407 return self._request(command_info[0], url, body=data)
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:431, in RemoteConnection._request(self, method, url, body)
#     428     body = None
#     430 if self._client_config.keep_alive:
# --> 431     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     432     statuscode = response.status
#     433 else:
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df_subj = pd.DataFrame(rows_subj).drop_duplicates().reset_index(drop=True)
df_subj.to_csv(DATA_DIR / "df_subj_temp_bronze.csv", index=False, encoding="utf-8-sig")
len(df_subj)
