# %% [markdown]
# # Scraping of Programmes and Courses Data
#
# Notebook pipeline that
#
# 1) Loads both pages in studiegids and collects all programme URLs
# 2) Clicks through every programme, then every track, then every year, and reads the visible tables
# 3) Enriches each programme with text from vu.nl base, curriculum, future, and admissions
# 4) Saves tidy CSV and JSON for programmes and subjects

# %% [markdown]
# ## 1) Import modules

# %%
import pandas as pd
from pathlib import Path
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

from scraper_modules.studiegids import StudiegidsScraper
from scraper_modules.vu_pages import VuPages

# %% [markdown]
# ## 2) Setup directories, Selenium, Faculties

# %%
DATA_DIR = Path("data")
CACHE_DIR = DATA_DIR / "vu_cache"
DATA_DIR.mkdir(exist_ok=True, parents=True)

chrome_options = Options()
# chrome_options.add_argument("--headless=new")  # turn on in CI runs
chrome_options.add_argument("--start-maximized")
driver = webdriver.Chrome(options=chrome_options)

sg = StudiegidsScraper(driver, debug=False)
vu = VuPages(CACHE_DIR)

LISTING_URL = "https://studiegids.vu.nl/en/bachelor/2025-2026#/"
FACULTIES = ["School of Business and Economics", "Faculty of Science", "Faculty of Humanities"]

# %% [markdown]
# ## 3) Programmes list

# %%
programmes = sg.list_programmes(LISTING_URL, FACULTIES)
len(programmes), programmes[:3]
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# File c:\Users\lmo820\OneDrive - Vrije Universiteit Amsterdam\Desktop\vita-vu.github.io\src\data\notebooks\scraper_modules\studiegids.py:189, in StudiegidsScraper.list_programmes(self, listing_url, faculties, english_label_css)
#     188 try:
# --> 189     lang = self.wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, english_label_css)))
#     190     d.execute_script("arguments[0].scrollIntoView({block:'center'});", lang)
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\support\wait.py:138, in WebDriverWait.until(self, method, message)
#     137     time.sleep(self._poll)
# --> 138 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff7fecea235
# 	0x7ff7fea42630
# 	0x7ff7fe7d16dd
# 	0x7ff7fe82a27e
# 	0x7ff7fe82a58c
# 	0x7ff7fe87ed77
# 	0x7ff7fe87baba
# 	0x7ff7fe81b0ed
# 	0x7ff7fe81bf63
# 	0x7ff7fed15d60
# 	0x7ff7fed0fe8a
# 	0x7ff7fed31005
# 	0x7ff7fea5d71e
# 	0x7ff7fea64e1f
# 	0x7ff7fea4b7c4
# 	0x7ff7fea4b97f
# 	0x7ff7fea318e8
# 	0x7ffe9741e8d7
# 	0x7ffe9902c53c
#
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 programmes = sg.list_programmes(LISTING_URL, FACULTIES)
#       2 len(programmes), programmes[:3]
#
# File c:\Users\lmo820\OneDrive - Vrije Universiteit Amsterdam\Desktop\vita-vu.github.io\src\data\notebooks\scraper_modules\studiegids.py:194, in StudiegidsScraper.list_programmes(self, listing_url, faculties, english_label_css)
#     192     lang.click()
#     193 except Exception:
# --> 194     lab = self.wait.until(EC.element_to_be_clickable((By.XPATH, "//label[contains(translate(., 'ABCDEFGHIJKLMNOPQRSTUVWXYZ','abcdefghijklmnopqrstuvwxyz'), 'english')]")))
#     195     d.execute_script("arguments[0].scrollIntoView({block:'center'});", lab)
#     196     time.sleep(0.2)
#
# File c:\Users\lmo820\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\support\wait.py:138, in WebDriverWait.until(self, method, message)
#     136         break
#     137     time.sleep(self._poll)
# --> 138 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff7fecea235
# 	0x7ff7fea42630
# 	0x7ff7fe7d16dd
# 	0x7ff7fe82a27e
# 	0x7ff7fe82a58c
# 	0x7ff7fe87ed77
# 	0x7ff7fe87baba
# 	0x7ff7fe81b0ed
# 	0x7ff7fe81bf63
# 	0x7ff7fed15d60
# 	0x7ff7fed0fe8a
# 	0x7ff7fed31005
# 	0x7ff7fea5d71e
# 	0x7ff7fea64e1f
# 	0x7ff7fea4b7c4
# 	0x7ff7fea4b97f
# 	0x7ff7fea318e8
# 	0x7ffe9741e8d7
# 	0x7ffe9902c53c
